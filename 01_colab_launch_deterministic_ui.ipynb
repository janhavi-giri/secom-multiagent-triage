# %% [markdown]
# # SECOM Multi-Agent Excursion Triage — Colab Launcher
# This notebook installs dependencies and launches the **deterministic** Gradio Ops Console (no LLM required).
#
# **Dataset:** SECOM (UCI ML Repository), DOI: 10.24432/C54305

# %%
# !git clone https://github.com/<YOUR_GITHUB_USERNAME>/secom-multiagent-triage.git
# %cd secom-multiagent-triage

# %%
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Launch the deterministic UI
# If prompted, open the **public Gradio link** printed below.

# %%
# !python -m src.ui_gradio

# %% [markdown]
# ### Notes
# - The app downloads SECOM from the UCI repository at runtime.
# - SECOM has no real MES genealogy; this demo uses synthetic tool/lot IDs.
