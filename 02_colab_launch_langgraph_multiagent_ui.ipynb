# %% [markdown]
# # SECOM LangGraph Multi-Agent Triage — Colab Launcher
# This notebook installs dependencies and launches the **LangGraph ReAct** multi-agent Gradio UI.
#
# **Requires:** `OPENAI_API_KEY` in Colab Secrets or set below.
#
# **Architecture:** Supervisor → ReAct Specialist Agents → Synthesizer (LangGraph + LangChain)

# %%
# !git clone https://github.com/<YOUR_GITHUB_USERNAME>/secom-multiagent-triage.git
# %cd secom-multiagent-triage

# %%
# !pip -q install -r requirements.txt

# %% [markdown]
# ## Set your OpenAI API key
# Option A (recommended): Colab **Secrets** → add `OPENAI_API_KEY`.
# Option B: set it here (not recommended for public sharing).

# %%
# Option B (not recommended for public notebooks)
# import os
# os.environ['OPENAI_API_KEY'] = 'YOUR_KEY'

# %% [markdown]
# ## Launch the LangGraph multi-agent UI
# The UI runs deterministic agents first (CaseFile), then lets you query via ReAct LLM agents.

# %%
# !python -m src.ui_gradio_llm
